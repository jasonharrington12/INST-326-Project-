# %%
member_id = [
  "John Doe",
 "Jane Smith",
  "Alice Lee",
  "Jane Doe",
  "Mary brown"
]

print(member_id[0])
print(member_id[2])

def delete_book(book_id):
  """ removes book from catalog if lost, damaged, or outdated"""
  for book in books:
    if book["id"] == book_id:
      books.remove(book)
      return True
  return False

def get_available_books(self):
    available_books = [book for book in self.books if book["available"]]
    if not available_books:
      print("No books are currently available.")
      return []

    print("Available Books:")
    for book in available_books:
      print(f" - {book['title']} by {book['author']} ({book['genre']})")
    return available_books

def get_member_history(self, member_id):
    """
    returns borrow history for a memeber
    includes book title, status, and due dates
    """

    history = [ ]

    for record in self.checkouts:
      if record["member_id"] == member_id:
        for book in self.books:
          if book["id"] == record["book_id"]:
            if book["available"]:
              status = "returned"
            else:
              status = "Checked out"

          history.append({
              "title": book["title"],
              "author": book["author"],
              "genre": book["genre"],
              "due_date": record["due_date"],
              "status": status
          })
    if not history:
      print(f"No borrowing history found for member id {member_id}.")
    return []

    print(f"Borrowing history for member ID {member_id}:")
    print("-" * 40)
    for idx, item in enumerate(history, start=1):
      print(f"{idx}. {item['title']} by {item['author']}")
      print(f"  Genre: {item['genre']}")
      print(f"  Status: {item['status']}")
      print(f"  Due Date: {item['due_date']}")
      print("-" * 40 )

    return history
# Ade's Peer Review

# By - Joseph Glover

# Hey ADE I thought your code was really clear and easy to follow, especially
# with the way you handled listing available books and tracking member history.
# The get_available_books function gives nice, readable output and makes it easy
# to see what’s left in the catalog. I like how you separated the logic for
# deleting books and checking history, which keeps the code organized. My only
# advice to you is to just watch out for small things like returning the history
# list before the print statements (they won’t run), but overall, great job!
# Out:
# John Doe
# Alice Lee
